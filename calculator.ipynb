# %%
import numpy
import matplotlib.pyplot as plt

from datetime import date, datetime
from dateutil.relativedelta import relativedelta

try:
    # Try local import first
    from src.mortgage_calculator_helpers.calculate_tax import print_hello
except (ImportError, ModuleNotFoundError):
    # Fallback: fetch from GitHub and retry import
    import cloud_import

    cloud_import.add_gh_repo("nizwant", "mortgage-calculator", "main")
    from src.mortgage_calculator_helpers.calculate_tax import print_hello

# %%
print_hello()

# %% [markdown]
# ## Configuration

# %% [markdown]
# ## Disposable income and savings

# %% [markdown]
# ## Down payment

# %% [markdown]
# ## Mortgage cost and overpayments

# %% [markdown]
# describe here costs and risks associated with mortgage, how to minimize it, tips etc.

# %% [markdown]
# ## Total cost and final optimization
